# %%
# !cd .. && pwd && make test_nn
# Out:
# /Users/bmiller/src/projects/idris-dl
# idris2 --exec main TestNN.idr
# Loading MNIST training data...
# Loaded 60000 training samples
# Loading MNIST test data...
# Loaded 10000 test samples
#
# Testing untrained network...
# Initial accuracy: 2.0%
#
# Training network on 1000 samples...
# Epoch 3...
# Epoch 2...
# Epoch 1...
#
# Evaluating trained network...
# Final accuracy: 82.0%
# Improvement: 80.0%
#
# Sample predictions:
#   ✓ Sample 1: Predicted 7, Actual 7
#   ✓ Sample 2: Predicted 2, Actual 2
#   ✓ Sample 3: Predicted 1, Actual 1
#   ✓ Sample 4: Predicted 0, Actual 0
#   ✓ Sample 5: Predicted 4, Actual 4

# %%
import visualize_rotations as vr

# %%
vr.visualize_rotations(5)
# Out:
# Saved visualization to rotation_visualization.png
